# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, GRU, SimpleRNN, Dense
from tensorflow.keras.utils import to_categorical

# %%
# Load the IMDb dataset
max_features = 10000
max_len = 500
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
x_train = pad_sequences(x_train, maxlen=max_len)
x_test = pad_sequences(x_test, maxlen=max_len)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
# Create models
def create_model(model_type):
    model = Sequential()
    model.add(Embedding(max_features, 32, input_length=max_len))
    if model_type == 'LSTM':
        model.add(LSTM(32))
    elif model_type == 'GRU':
        model.add(GRU(32))
    elif model_type == 'RNN':
        model.add(SimpleRNN(32))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
# Train models and collect history
model_types = ['LSTM', 'GRU', 'RNN']
histories = []

plt.figure(figsize=(10, 6))

for model_type in model_types:
    model = create_model(model_type)
    history = model.fit(x_train, y_train, epochs=5, batch_size=128, validation_split=0.2, verbose=1)
    plt.plot(history.history['accuracy'], label=f'{model_type} Accuracy')

plt.title('Comparison of Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid()
plt.legend()
plt.savefig("plot.png")
plt.show()
# Out:
# Epoch 1/5
# 157/157 [==============================] - 38s 221ms/step - loss: 0.5069 - accuracy: 0.7572 - val_loss: 0.3495 - val_accuracy: 0.8658
# Epoch 2/5
# 157/157 [==============================] - 30s 194ms/step - loss: 0.2994 - accuracy: 0.8816 - val_loss: 0.3793 - val_accuracy: 0.8338
# Epoch 3/5
# 157/157 [==============================] - 31s 196ms/step - loss: 0.2036 - accuracy: 0.9253 - val_loss: 0.3105 - val_accuracy: 0.8850
# Epoch 4/5
# 157/157 [==============================] - 30s 194ms/step - loss: 0.1502 - accuracy: 0.9492 - val_loss: 0.3218 - val_accuracy: 0.8802
# Epoch 5/5
# 157/157 [==============================] - 30s 194ms/step - loss: 0.1175 - accuracy: 0.9626 - val_loss: 0.3350 - val_accuracy: 0.8796
# Epoch 1/5
# 157/157 [==============================] - 30s 183ms/step - loss: 0.5882 - accuracy: 0.6754 - val_loss: 0.4403 - val_accuracy: 0.7918
# Epoch 2/5
# 157/157 [==============================] - 29s 182ms/step - loss: 0.3087 - accuracy: 0.8711 - val_loss: 0.3295 - val_accuracy: 0.8642
# Epoch 3/5
# 157/157 [==============================] - 27s 175ms/step - loss: 0.2016 - accuracy: 0.9238 - val_loss: 0.3203 - val_accuracy: 0.8728
# Epoch 4/5
# 157/157 [==============================] - 27s 175ms/step - loss: 0.1592 - accuracy: 0.9426 - val_loss: 0.3507 - val_accuracy: 0.8668
# Epoch 5/5
# 157/157 [==============================] - 29s 185ms/step - loss: 0.1276 - accuracy: 0.9564 - val_loss: 0.3683 - val_accuracy: 0.8700
# Epoch 1/5
# 157/157 [==============================] - 15s 87ms/step - loss: 0.5832 - accuracy: 0.6855 - val_loss: 0.4437 - val_accuracy: 0.8056
# Epoch 2/5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.3784 - accuracy: 0.8299 - val_loss: 0.5933 - val_accuracy: 0.6698
# Epoch 3/5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.3727 - accuracy: 0.8365 - val_loss: 0.4034 - val_accuracy: 0.8286
# Epoch 4/5
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2186 - accuracy: 0.9208 - val_loss: 0.3924 - val_accuracy: 0.8436
# Epoch 5/5
# 157/157 [==============================] - 15s 93ms/step - loss: 0.1319 - accuracy: 0.9572 - val_loss: 0.4283 - val_accuracy: 0.8446
